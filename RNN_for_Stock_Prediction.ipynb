# %% [markdown]
# <a href="https://colab.research.google.com/github/chenitiaaas/Memprediksi-Harga-Saham-Menggunakan-Reccurent-Neural-Network-RNN-/blob/main/RNN_for_Stock_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import function
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt


# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/jst/uas/BRMS.JK.csv")

# %%
#Mari kita periksa beberapa contoh dari data kita
data.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close       Volume
# 0  2019-01-01  50.0  50.0  50.0   50.0       50.0          0.0
# 1  2019-01-02  50.0  50.0  50.0   50.0       50.0      54500.0
# 2  2019-01-03  50.0  51.0  50.0   50.0       50.0    7592200.0
# 3  2019-01-04  50.0  51.0  50.0   50.0       50.0   14309400.0
# 4  2019-01-07  50.0  55.0  50.0   51.0       51.0  219248800.0

# %%
print("Data Shape -->", data.shape)
# Out:
# Data Shape --> (1212, 7)

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1211.000000  1211.000000  1211.000000  1211.000000  1211.000000
# mean    110.997287   113.727905   108.338377   110.666886   110.666886
# std      64.253253    66.026106    62.060897    63.869623    63.869623
# min      46.984577    46.984577    46.984577    46.984577    46.984577
# 25%      50.000000    50.000000    50.000000    50.000000    50.000000
# 50%      93.000000    95.000000    91.000000    93.000000    93.000000
# 75%     170.000000   174.000000   166.000000   170.000000   170.000000
# max     300.000000   304.000000   280.000000   294.000000   294.000000
#
#              Volume
# count  1.211000e+03
# mean   3.370007e+08
# std    5.271088e+08
# min    0.000000e+00
# 25%    2.792235e+07
# 50%    1.788220e+08
# 75%    4.168459e+08
# max    5.488746e+09

# %%
print("Do you have a null column? \n", data.isna().sum())
# Menampilkan nilai yang null
print("Nilai yang null:\n", data[data.isnull().any(axis=1)])
# Out:
# Do you have a null column?
#  Date         0
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64
# Nilai yang null:
#             Date  Open  High  Low  Close  Adj Close  Volume
# 121  2019-06-19   NaN   NaN  NaN    NaN        NaN     NaN

# %%
# Menghapus baris yang mengandung nilai null
data = data.dropna()

# %%
print("Do you have a null column? \n", data.isna().sum())
# Menampilkan nilai yang null
# Out:
# Do you have a null column?
#  Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Split data
training_size = int(len(data)*0.80)
data_len = len(data)

train, test = data[0:training_size],data[training_size:data_len]

# %%
print("Training Size --> ", training_size)
print("total length of data --> ", data_len)
print("Train length --> ", len(train))
print("Test length --> ", len(test))
# Out:
# Training Size -->  968
# total length of data -->  1211
# Train length -->  968
# Test length -->  243

# %%
# Bagian data yang akan kita gunakan sebagai pelatihan
train = train.loc[:, ["Open"]].values

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train)

# %%
end_len = len(train_scaled)
X_train = []
y_train = []
timesteps = 40

for i in range(timesteps, end_len):
    X_train.append(train_scaled[i - timesteps:i, 0])
    y_train.append(train_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print("X_train --> ", X_train.shape)
print("y_train shape --> ", y_train.shape)
# Out:
# X_train -->  (928, 40, 1)
# y_train shape -->  (928,)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# %%
regressor = Sequential()

regressor.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True, input_shape = (X_train.shape[1],1)))
regressor.add(Dropout(0.2))

regressor.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(SimpleRNN(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

# %%
regressor.compile(optimizer= "adam", loss = "mean_squared_error")

# %%
epochs = 100
batch_size = 20

# %%
regressor.fit(X_train, y_train, epochs = epochs, batch_size = batch_size)
# Out:
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 0.4703
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.2701
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.1904
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.1419
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.1001
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0628
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0461
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.0391
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0294
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0297
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0196
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0208
# Epoch 13/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0188
# Epoch 14/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0167
# Epoch 15/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0156
# Epoch 16/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0164
# Epoch 17/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0125
# Epoch 18/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0135
# Epoch 19/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0142
# Epoch 20/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0134
# Epoch 21/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0113
# Epoch 22/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0100
# Epoch 23/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0081
# Epoch 24/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0092
# Epoch 25/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 0.0082
# Epoch 26/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.0076
# Epoch 27/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0071
# Epoch 28/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0070
# Epoch 29/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0089
# Epoch 30/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0068
# Epoch 31/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0062
# Epoch 32/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0058
# Epoch 33/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0057
# Epoch 34/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0055
# Epoch 35/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0057
# Epoch 36/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0044
# Epoch 37/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.0050
# Epoch 38/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0076
# Epoch 39/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0060
# Epoch 40/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0037
# Epoch 41/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0036
# Epoch 42/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 0.0037
# Epoch 43/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0038
# Epoch 44/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0041
# Epoch 45/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0044
# Epoch 46/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0035
# Epoch 47/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0037
# Epoch 48/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0032
# Epoch 49/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0032
# Epoch 50/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0036
# Epoch 51/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0038
# Epoch 52/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0029
# Epoch 53/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0033
# Epoch 54/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0032
# Epoch 55/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0027
# Epoch 56/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0027
# Epoch 57/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0029
# Epoch 58/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0030
# Epoch 59/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0031
# Epoch 60/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0028
# Epoch 61/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0032
# Epoch 62/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0021
# Epoch 63/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0021
# Epoch 64/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0028
# Epoch 65/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 0.0024
# Epoch 66/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.0027
# Epoch 67/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0027
# Epoch 68/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0026
# Epoch 69/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0019
# Epoch 70/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0029
# Epoch 71/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0023
# Epoch 72/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0018
# Epoch 73/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0020
# Epoch 74/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0023
# Epoch 75/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0021
# Epoch 76/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0029
# Epoch 77/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 0.0024
# Epoch 78/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0025
# Epoch 79/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0023
# Epoch 80/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0022
# Epoch 81/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0022
# Epoch 82/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0018
# Epoch 83/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0018
# Epoch 84/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.0018
# Epoch 85/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0016
# Epoch 86/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0014
# Epoch 87/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0019
# Epoch 88/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0020
# Epoch 89/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 0.0019
# Epoch 90/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.0021
# Epoch 91/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0017
# Epoch 92/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0022
# Epoch 93/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0019
# Epoch 94/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0025
# Epoch 95/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0018
# Epoch 96/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - loss: 0.0017
# Epoch 97/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0022
# Epoch 98/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0020
# Epoch 99/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0015
# Epoch 100/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0016

# %%
test.head()
# Out:
#            Date   Open   High    Low  Close  Adj Close       Volume
# 969  2022-11-29  176.0  181.0  175.0  179.0      179.0  143211600.0
# 970  2022-11-30  179.0  183.0  178.0  183.0      183.0  161544600.0
# 971  2022-12-01  183.0  187.0  182.0  185.0      185.0  182282900.0
# 972  2022-12-02  185.0  192.0  184.0  184.0      184.0  400670200.0
# 973  2022-12-05  186.0  186.0  177.0  178.0      178.0  172239800.0

# %%
real_price = test.loc[:, ["Open"]].values
print("Real Price Shape --> ", real_price.shape)
# Out:
# Real Price Shape -->  (243, 1)

# %%
dataset_total = pd.concat((data[["Open"]], test[["Open"]]), axis=0)
inputs = dataset_total[len(dataset_total) - len(test) - timesteps:].values.reshape(-1, 1)
inputs = scaler.transform(inputs)

# %%
X_test = []

for i in range(timesteps, 283):
    X_test.append(inputs[i-timesteps:i, 0])
X_test = np.array(X_test)

print("X_test shape --> ", X_test.shape)
# Out:
# X_test shape -->  (243, 40)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predict = regressor.predict(X_test)
predict = predict.reshape(-1, 1)  # Reshape to match the number of features
predict = scaler.inverse_transform(predict)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step

# %%
plt.plot(real_price, color = "red", label = "Real Stock Price")
plt.plot(predict, color = "black", label = "Predict Stock Price")
plt.title("Stock Price Prediction")
plt.xlabel("Time")
plt.ylabel("BRMS Stock Price")
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# Use real_price as y_actual and predict as y_predicted
mse = mean_squared_error(real_price, predict)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 174.80746881682413
